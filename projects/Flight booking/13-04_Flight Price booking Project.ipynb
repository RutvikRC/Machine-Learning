# %%
import pandas as pd
#df = pd.read_csv(r"C:\Users\Dell\Downloads\Flight_Booking (2).csv")
df = pd.read_csv("Flight_Booking.csv")

# %%
df
# Out:
#         Unnamed: 0   airline   flight source_city departure_time stops  \
# 0                0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1                1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2                2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3                3   Vistara   UK-995       Delhi        Morning  zero
# 4                4   Vistara   UK-963       Delhi        Morning  zero
# ...            ...       ...      ...         ...            ...   ...
# 184018      184018  GO_FIRST   G8-302     Chennai  Early_Morning   one
# 184019      184019  GO_FIRST   G8-302     Chennai  Early_Morning   one
# 184020      184020  GO_FIRST   G8-302     Chennai  Early_Morning   one
# 184021      184021  GO_FIRST   G8-304     Chennai      Afternoon   one
# 184022      184022  GO_FIRST   G8-302     Chennai  Early_Morning   one
#
#          arrival_time destination_city    class  duration  days_left  price
# ...

# %%
#dropping the column "Unamed:0"
df = df.drop(columns=["Unnamed: 0"])

# %%
df.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184023 entries, 0 to 184022
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           184023 non-null  object
#  1   flight            184023 non-null  object
#  2   source_city       184023 non-null  object
#  3   departure_time    184023 non-null  object
#  4   stops             184023 non-null  object
#  5   arrival_time      184023 non-null  object
#  6   destination_city  184023 non-null  object
#  7   class             184023 non-null  object
#  8   duration          184023 non-null  float64
#  9   days_left         184023 non-null  int64
#  10  price             184023 non-null  int64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 15.4+ MB

# %%
df.describe(include="all")
# Out:
#         airline  flight source_city departure_time   stops arrival_time  \
# count    184023  184023      184023         184023  184023       184023
# unique        6    1480           6              6       3            6
# top     Vistara  UK-706       Delhi        Morning     one        Night
# freq      58701    1806       43027          42423  148083        55492
# mean        NaN     NaN         NaN            NaN     NaN          NaN
# std         NaN     NaN         NaN            NaN     NaN          NaN
# min         NaN     NaN         NaN            NaN     NaN          NaN
# 25%         NaN     NaN         NaN            NaN     NaN          NaN
# 50%         NaN     NaN         NaN            NaN     NaN          NaN
# 75%         NaN     NaN         NaN            NaN     NaN          NaN
# max         NaN     NaN         NaN            NaN     NaN          NaN
#
#        destination_city    class       duration      days_left          price
# ...

# %%
df.isnull().sum()
# Out:
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# dtype: int64

# %%
#handling the null values
#dropna()
#fillna()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#1) Plot the best suitable graph if the price varies with different airlines.

plt.figure(figsize=(15,5))
sns.lineplot(x=df['airline'],y=df['price'])
plt.title('Airlines vs Price', fontsize=15)
plt.xlabel('Airline', fontsize=15)
plt.ylabel('Price', fontsize=15)
plt.show()

# %%
#The lowest price is of AirAsia
##The highest price is of Vistara

# %%
#2) Is the price affected when tickets are bought just 1 or 2 days before departure?
#Show the stats in graphical form.

df.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x=df['days_left'], y=df['price'], color='blue')
plt.title('Days left for Departure vs Ticket Price', fontsize=15)
plt.xlabel('Days left for Departure', fontsize=15)
plt.ylabel('Ticket Price', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.lineplot(x='days_left',y='price', data=df, hue='airline')
# Out:
# <AxesSubplot:xlabel='days_left', ylabel='price'>

# %%
# From the above graph we can clearly see that price is affected when tickets are bought in
# just 1 or 2 days before departure and there is increase in price.

# %%
#3) Which airline has been used by the most number of passengers ?

df['airline'].value_counts()
# Out:
# Vistara      58701
# Air_India    42766
# Indigo       37280
# GO_FIRST     22130
# AirAsia      14929
# SpiceJet      8217
# Name: airline, dtype: int64

# %%
# Vistara has been used by the most number of passengers

# %%
#4) How does the ticket price vary between Economy and Business class for all airlines?
#Show the insights with the best suitable graph.

# %%
plt.figure(figsize=(10,8))
sns.barplot(x='class', y='price', data=df, hue='airline')
# Out:
# <AxesSubplot:xlabel='class', ylabel='price'>

# %%
#5) How many passengers are travelling in business class on a direct flight 

#df.head()

df.loc[(df['class']=='Business') & df['stops']=='zero'].shape
# Out:
# (0, 11)

# %%
#6) Which city has the lowest take off of flights

df['source_city'].value_counts()
# Out:
# Delhi        43027
# Mumbai       41038
# Bangalore    35620
# Kolkata      32874
# Hyderabad    27936
# Chennai       3528
# Name: source_city, dtype: int64

# %%
#Chennai has the lowest take off of flights

# %%
#7) What is the average price of all airlines from Delhi to Mumbai 

fig, ax= plt.subplots(1,2, figsize=(20,6))

sns.barplot(x='source_city',y='price', data=df, ax=ax[0])
sns.barplot(x='destination_city',y='price', data=df, ax=ax[1])
# Out:
# <AxesSubplot:xlabel='destination_city', ylabel='price'>

# %%
df1 = df.loc[(df['source_city']=="Delhi")&(df['destination_city']=="Mumbai")]

# %%
df1.describe()
# Out:
#           duration    days_left         price
# count  9982.000000  9982.000000   9982.000000
# mean      9.537000    25.915949   6059.826087
# std       7.048232    13.613198   3785.763647
# min       2.000000     1.000000   2281.000000
# 25%       2.330000    14.000000   3100.000000
# 50%       7.670000    26.000000   5284.000000
# 75%      13.750000    38.000000   6724.000000
# max      30.080000    49.000000  31260.000000

# %%
#Ans is 6059.82

# %%
#countplt for visualizing the categorical variables
plt.figure(figsize=(15,5))
sns.countplot(x=df['airline'])
plt.title("Freq of Airline")

plt.figure(figsize=(15,5))
sns.countplot(x=df["class"], data=df)
plt.title("Class Frequency")
# Out:
# Text(0.5, 1.0, 'Class Frequency')

# %%
#9) Which feature is highly dependent on the target variable ?
df.corr()
# Out:
#            duration  days_left     price
# duration   1.000000  -0.043179  0.283049
# days_left -0.043179   1.000000 -0.555854
# price      0.283049  -0.555854  1.000000

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184023 entries, 0 to 184022
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           184023 non-null  object
#  1   flight            184023 non-null  object
#  2   source_city       184023 non-null  object
#  3   departure_time    184023 non-null  object
#  4   stops             184023 non-null  object
#  5   arrival_time      184023 non-null  object
#  6   destination_city  184023 non-null  object
#  7   class             184023 non-null  object
#  8   duration          184023 non-null  float64
#  9   days_left         184023 non-null  int64
#  10  price             184023 non-null  int64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 15.4+ MB

# %%
#  8) Convert all the attributes into integer data type which are of object data type except
#Flight column.

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

df["airline"] = le.fit_transform(df["airline"])
df["source_city"] = le.fit_transform(df["source_city"])
df["departure_time"] = le.fit_transform(df["departure_time"])
df["arrival_time"]=le.fit_transform(df["arrival_time"])
df["destination_city"]=le.fit_transform(df["destination_city"])
df["class"]=le.fit_transform(df["class"])
df['stops'] = le.fit_transform(df['stops'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184023 entries, 0 to 184022
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           184023 non-null  int64
#  1   flight            184023 non-null  object
#  2   source_city       184023 non-null  int64
#  3   departure_time    184023 non-null  int64
#  4   stops             184023 non-null  int32
#  5   arrival_time      184023 non-null  int64
#  6   destination_city  184023 non-null  int64
#  7   class             184023 non-null  int64
#  8   duration          184023 non-null  float64
#  9   days_left         184023 non-null  int64
#  10  price             184023 non-null  int64
# dtypes: float64(1), int32(1), int64(8), object(1)
# memory usage: 14.7+ MB

# %%
df = df.drop(columns=['flight'])

# %%
#Mutlicollinearity - vif

from statsmodels.stats.outliers_influence import variance_inflation_factor 
col_list = []
for col in df.columns:
    if ((df[col].dtype != 'object') & (col != 'price') ):
        col_list.append(col)
        
col_list
# Out:
# ['airline',
#  'source_city',
#  'departure_time',
#  'stops',
#  'arrival_time',
#  'destination_city',
#  'class',
#  'duration',
#  'days_left']

# %%
X = df[col_list]
vif_data = pd.DataFrame()
vif_data['feature'] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))] 
print(vif_data)
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1738: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.uncentered_tss
#             feature       VIF
# 0           airline  3.237984
# 1       source_city  3.148233
# 2    departure_time  2.653652
# 3             stops  1.426612
# 4      arrival_time  3.586363
# 5  destination_city  2.747195
# 6             class       NaN
# 7          duration  3.799511
# 8         days_left  3.784716

# %%
#Decision Tree
X = df.drop(columns=['price'])
y = df['price']

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=78)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

# %%
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import *

dt=DecisionTreeRegressor()
dt.fit(x_train,y_train) #training
y_pred=dt.predict(x_test) #predicting values
r2_score(y_test,y_pred)
# Out:
# 0.757029732489

# %%
sns.distplot(y_test,label="Actual")
sns.distplot(y_pred,label="Predicted")
plt.title("decision Tree")
plt.legend()
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#MSE
#RMSE

# %%
#Random Forest
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train) #training
y_pred=rfr.predict(x_test) #predicting
r2_score(y_test,y_pred)
# Out:
# 0.859456426701789

# %%
#MSE
#RMSE

# %%
sns.distplot(y_test,label="Actual")
sns.distplot(y_pred,label="Predicted")
plt.title("Random Forest")
plt.legend()
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Which one is best algorithm out of the two algorithms used on this dataset  ==> Random Forest
